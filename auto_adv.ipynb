# %%
from obj_dect import run_main, check_dir
from mod import process_ano, play_ano

# %%
check_dir()
# Out:
# 0
# 1

# %%
number = 10
mode = "train"

# %%
for i in range(1, number + 1):
    print(i)
    run_main(i, mode)
# Out:
# 1
# *************************************************
# mode: TRAIN
# **********************************************
#
# vid no: 1
# 0
# 0
#
# 0: 352x640 10 cars, 2 buss, 3 trucks, 98.0ms
# Speed: 4.0ms preprocess, 98.0ms inference, 2245.2ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 1
# 1
# 0
#
# 0: 352x640 9 cars, 1 bus, 3 trucks, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 1
# 2
# 0
#
# 0: 352x640 9 cars, 1 bus, 3 trucks, 19.0ms
# Speed: 3.0ms preprocess, 19.0ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 1
# 3
# 0
#
# 0: 352x640 12 cars, 1 bus, 2 trucks, 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 1
# 4
# 0
#
# 0: 352x640 12 cars, 1 bus, 2 trucks, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 1
# 5
# ...
