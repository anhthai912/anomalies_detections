# %%
BOTSORT = [
    [0.23566384190934078, [1, 15, 1, 95, 396], 0.14304057487512437, [[11, 51], [7, 0]]],
    [0.271477329861185, [1, 30, 1, 90, 261], 0.12386861726617579, [[11, 42], [7, 0]]],
    [0.35115018478146065, [1, 45, 1, 100, 296], 0.09020179397530649, [[11, 28], [7, 0]]],
    [0.36162012741413285, [1, 60, 1, 95, 291], 0.07951240294584376, [[11, 27], [7, 0]]],
    [0.36022943463977325, [1, 75, 1, 85, 256], 0.06340346993658943, [[10, 24], [8, 0]]],
    [0.3800515935375998, [1, 90, 1, 95, 261], 0.08787617550976046, [[10, 20], [8, 0]]],

    [0.36873770167601577, [1, 15, 2, 100, 351], 0.03718489006818113, [[9, 20], [9, 0]]],
    [0.509322706623303, [1, 30, 2, 100, 261], 0.09710974734959942, [[11, 10], [7, 0]]],
    [0.4920136909994063, [1, 45, 2, 100, 261], 0.07064080589001037, [[9, 7], [9, 0]]],
    [0.4891696260066813, [1, 60, 2, 100, 261], 0.1303651093214556, [[9, 5], [9, 0]]],
    [0.48910306971677914, [1, 75, 2, 100, 261], 0.13048343161461506, [[9, 5], [9, 0]]],
    [0.5045571460961314, [1, 90, 2, 100, 256], 0.13104047061221813, [[9, 4], [9, 0]]],

    [0.4266327465123248, [1, 15, 3, 100, 261], 0.07562904922329616, [[9, 12], [9, 0]]],
    [0.5244781120763288, [1, 30, 3, 100, 261], 0.1258698132061187, [[9, 3], [9, 0]]],
    [0.5213079137114509, [1, 45, 3, 95, 261], 0.13115347714758172, [[9, 3], [9, 0]]],
    [0.5179404010625339, [1, 60, 3, 100, 256], 0.13676599822911006, [[9, 3], [9, 0]]],
    [0.49613186574642076, [1, 75, 3, 100, 256], 0.10076099333461228, [[8, 3], [10, 0]]],
    [0.5005673324276637, [1, 90, 3, 100, 51], 0.1240071682515885, [[8, 2], [10, 0]]],

    [0.5073433675492363, [1, 15, 4, 95, 261], 0.12624197810964874, [[9, 4], [9, 0]]],
    [0.5387976407790488, [1, 30, 4, 100, 261], 0.1319371343004213, [[9, 2], [9, 0]]],
    [0.5632864771125935, [1, 45, 4, 100, 256], 0.09248289798526582, [[9, 2], [9, 0]]],
    [0.49984506789297695, [1, 60, 4, 100, 26], 0.15651144793060134, [[8, 1], [10, 0]]],
    [0.37110986408342983, [1, 75, 4, 100, 1], 0.16500280581228285, [[6, 3], [12, 0]]],
    [0.18627336964929364, [1, 90, 4, 100, 1], 0.1928153981863943, [[3, 5], [15, 0]]],


]

# %%
BYTETRACK = [
    [0.23696511792373565, [1, 15, 1, 90, 321], 0.15239400127279165, [[13, 62], [5, 0]]],
    [0.2982703713624098, [1, 30, 1, 95, 396], 0.14586211837128094, [[11, 34], [7, 0]]],
    [0.41456575651410116, [1, 45, 1, 95, 296], 0.05925462944877059, [[13, 28], [5, 0]]],
    [0.4639454015757386, [1, 60, 1, 95, 291], 0.036421089035004524, [[13, 23], [5, 0]]],
    [0.4201483490921232, [1, 75, 1, 100, 261], 0.1024103451213733, [[11, 18], [7, 0]]],
    [0.4588467780795142, [1, 90, 1, 100, 231], 0.13966229110091083, [[12, 15], [6, 0]]],

    [0.4227991537451237, [1, 15, 2, 85, 351], 0.06631853547951845, [[12, 23], [6, 0]]],
    [0.5557267406269567, [1, 30, 2, 100, 261], 0.09694404648119527, [[12, 9], [6, 0]]],
    [0.5528071640981216, [1, 45, 2, 100, 231], 0.11550853744300559, [[10, 4], [8, 0]]],
[0.536778145245489, [1, 30, 4, 100, 261], 0.13519076599337893, [[9, 2], [9, 0]]],
[0.5650983583281357, [1, 45, 4, 100, 256], 0.12095810926734456, [[9, 1], [9, 0]]],
[0.46474489931473945, [1, 60, 4, 100, 51], 0.18669642619920596, [[8, 2], [10, 0]]],
[0.3094954935903477, [1, 75, 4, 65, 46], 0.1953117166650958, [[5, 3], [13, 0]]],
[0.1992099455638249, [1, 90, 4, 70, 21], 0.2031602177447004, [[3, 3], [15, 0]]],

]

# %%
join = BYTETRACK + OCSORT

# %%
bot_best = max(BOTSORT)
bot_best
# Out:
# [0.5632864771125935,
#  [1, 45, 4, 100, 256],
#  0.09248289798526582,
#  [[9, 2], [9, 0]]]

# %%
max(join)
# Out:
# [0.6222494019554686,
#  [1, 15, 4, 100, 261],
#  0.12319402451729417,
#  [[11, 2], [7, 0]]]

# %%
oc_best = max(OCSORT)
oc_best
# Out:
# [0.5650983583281357,
#  [1, 45, 4, 100, 256],
#  0.12095810926734456,
#  [[9, 1], [9, 0]]]

# %%
byte_best = max(BYTETRACK)
byte_best
# Out:
# [0.6222494019554686,
#  [1, 15, 4, 100, 261],
#  0.12319402451729417,
#  [[11, 2], [7, 0]]]

# %%
sjoin = sorted(join)

# %%
super_list = sjoin

# %%
s4_byte = [item[0] for item in BYTETRACK]
s4_oc = [item[0] for item in OCSORT]
s4 = [item[0] for item in super_list]
nrmse = [item[2] for item in super_list] 
error = [item[1][0] for item in super_list] 
life = [item[1][1] for item in super_list] 
fr_skp = [item[1][2] for item in super_list] 
ano_range = [item[1][3] for item in super_list] 
min_time = [item[1][4] for item in super_list] 
# w_data = [s4, [error, life, fr_skp, ano_range, min_time], rmse, cm]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
y = s4_byte
y2 = s4_oc
x_c = [item[1][1] for item in OCSORT]
x_b = [item[1][1] for item in BYTETRACK] 

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x_b, y, label='S4_bytetrack', color='blue', marker='o')
plt.scatter(x_c, y2, label='S4_OCSORT', color='red', marker='o')
plt.title('S4 score base on Smin')
plt.xlabel('Smin')
plt.ylabel('S4 score')
plt.legend()
plt.grid(True)
plt.show()

# %%
x_c = [item[1][2] for item in OCSORT]
x_b = [item[1][2] for item in BYTETRACK] 

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x_b, y, label='S4_bytetrack', color='blue', marker='o')
plt.scatter(x_c, y2, label='S4_OCSORT', color='red', marker='o')
plt.xlabel('frame skipped')
plt.ylabel('S4 score')
plt.legend()
plt.grid(True)
plt.show()

# %%
x_c = [item[2] for item in OCSORT]
x_b = [item[2] for item in BYTETRACK] 

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x_b, y, label='S4_bytetrack', color='blue', marker='o')
plt.scatter(x_c, y2, label='S4_OCSORT', color='red', marker='o')
plt.xlabel('NRMSE')
plt.ylabel('S4 score')
plt.legend()
plt.grid(True)
plt.show()

# %%
x_c = [item[3][0][0] for item in OCSORT]
x_b = [item[3][0][0] for item in BYTETRACK] 

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x_b, y, label='S4_bytetrack', color='blue', marker='o')
plt.scatter(x_c, y2, label='S4_OCSORT', color='red', marker='o')
plt.xlabel('TP')
plt.ylabel('S4 score')
plt.legend()
plt.grid(True)
plt.show()

# %%
x_c = [item[3][0][1] for item in OCSORT]
x_b = [item[3][0][1] for item in BYTETRACK] 

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x_b, y, label='S4_bytetrack', color='blue', marker='o')
plt.scatter(x_c, y2, label='S4_OCSORT', color='red', marker='o')
plt.xlabel('FP')
plt.ylabel('S4 score')
plt.legend()
plt.grid(True)
plt.show()

# %%
x_c = [item[3][1][0] for item in OCSORT]
x_b = [item[3][1][0] for item in BYTETRACK] 

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x_b, y, label='S4_bytetrack', color='blue', marker='o')
plt.scatter(x_c, y2, label='S4_OCSORT', color='red', marker='o')
plt.xlabel('FN')
plt.ylabel('S4 score')
plt.legend()
plt.grid(True)
plt.show()
