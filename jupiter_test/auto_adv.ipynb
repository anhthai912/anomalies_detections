# %%
from obj_dect import run_main, run_main_img
from mod import process_ano, play_ano, check_dir

# %%
check_dir()
# Out:
# 0
# 1

# %%
number = 10
mode = "train"

# %%
# for i in range(1, number + 1):
#     print(i)
#     run_main(i, mode)
run_main_img(33, "train")
# Out:
# *************************************************
# mode: TRAIN
# **********************************************
#
# vid no: 33
# 0
# 0
#
# 0: 352x640 12 cars, 6 trucks, 111.6ms
# Speed: 8.0ms preprocess, 111.6ms inference, 2804.3ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 33
# 1
# 0
#
# 0: 352x640 12 cars, 6 trucks, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 33
# 2
# 0
#
# 0: 352x640 12 cars, 6 trucks, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 33
# 3
# 0
#
# 0: 352x640 13 cars, 6 trucks, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 33
# 4
# 0
#
# 0: 352x640 13 cars, 6 trucks, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# {}
# vid no: 33
# 5
# 0
#
# ...
